# %%
#https://cscircles.cemc.uwaterloo.ca

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
#Experimentation

print(1)
print('a')
print(1 + 2)
print("Hello" + ',' + " World" + '!')
print('abcde')
print("String: Hello! ", 1234, " <- Number")
# Out:
# 1
# a
# 3
# Hello, World!
# abcde
# String: Hello!  1234  <- Number
