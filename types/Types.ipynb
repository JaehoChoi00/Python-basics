# %%
x = "Hello, World!"
y = 35
z = max(x, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 x = "Hello, World!"
#       2 y = 35
# ----> 3 z = max(x, y)
#
# TypeError: '>' not supported between instances of 'int' and 'str'

# %%
# You can determine the type of an object by calling the type function on it.

print(type("Hello, World!"))
print(type(34))
print(type(1.234))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
x = 1.2
y = 2
z = x * y
print(x, y, z)
print(type(x), type(y), type(z))
# Out:
# 1.2 2 2.4
# <class 'float'> <class 'int'> <class 'float'>

# %%
# In fact, what Python really does when you mix a float 
# with an int is that it converts the int to a float, 
# and then works with the two floats.

# %%
# Sometimes, Python does let you combine strings and 
# numbers using arithmetic operators. 
print("hots" * 2)
# Out:
# hotshots

# %%
inputStr = "12"                          # a piece of user input
print("The input type is", type(inputStr))
x = int(inputStr)
print(x, "is of type", type(x), "and its square is", x*x)
print(inputStr * inputStr)               # this line should cause an error
# Out:
# The input type is <class 'str'>
# 12 is of type <class 'int'> and its square is 144
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 inputStr = "12"                          # a piece of user input
#       2 print("The input type is", type(inputStr))
#       3 x = int(inputStr)
#       4 print(x, "is of type", type(x), "and its square is", x*x)
# ----> 5 print(inputStr * inputStr)               # this line should cause an error
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
# Write a program to help you feed your friends at a party by doing some math about square pizzas. 
# Assume the grader defines a string inputStr for you, which is a decimal string meaning the side length L of the pizza in cm. 
# The area of the pizza should be computed using the formula A = L*L. 
# Then, assuming that each person needs to eat 100 cm2 of pizza, 
# compute the number of people it can feed, rounded down to the nearest integer.
# Example: if inputStr is "17.5", the area will be 306.25 cm2, so 3 is the correct output.

# %%
inputStr = "17.5" # decimal string of side length L of pizza in cm.

print(int(float(inputStr) * float(inputStr) / 100))
# Out:
# 3
