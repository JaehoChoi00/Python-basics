# %%
# Echoing a line of text
line = input()
print("The first line of input is:", line)
# Out:
# The first line of input is: Hello

# %%
inputString = input()
aFloat = float(inputString)
print(aFloat + 1)
print('Second line:', input())
# Out:
# 2.0
# Second line: Hello

# %%
myAge = 20
print("What is your age?")
age = input()
print("I see. Your age is " + age)
print("Which means our age gap is " + str(myAge - (int)(age)) + " compared to me!")
# Out:
# What is your age?
# I see. Your age is 1
# Which means our age gap is 19 compared to me!
