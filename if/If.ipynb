# %%
birthYear = 2004
currentYear = 2013
age = currentYear - birthYear
print('You are', age, 'years old')
# Out:
# You are 9 years old

# %%
birthYear = 2004
currentYear = 2013
age = currentYear - birthYear
if age > 65:
    print('Enjoy retirement!')
print('You are', age, 'years old')
# Out:
# You are 9 years old

# %%
birthYear = 2004
currentYear = 2026
age = currentYear - birthYear
if age > 65:
    print('Enjoy retirement!')
print('You are', age, 'years old')
# Out:
# You are 22 years old

# %%
birthYear = 1928
currentYear = 2026
age = currentYear - birthYear
if age > 65:
    print('Enjoy retirement!')
    print('You turn 100 in', 100+birthYear)
print('You are', age, 'years old')
# Out:
# Enjoy retirement!
# You turn 100 in 2028
# You are 98 years old

# %% [markdown]
# In the next exercise, we ask you to write a short program with boolean comparisons. We already saw in the examples above that "if x > y:" means "if x is greater than y". You might also find the following operations useful:
#
# if x < y: means "if x is less than y"
# if x >= y: means "if x is greater than or equal to y"
# if x <= y: means "if x is less than or equal to y"
#
# Write a program which reads an integer from input using pancakes = int(input()). If pancakes is more than 3, print out Yum! and if pancakes is not more than 3, print out Still hungry! instead.

# %%
pancakes = int(input())

if pancakes > 3:
    print("Yum!")
else:
    print("Still hungry!")
# Out:
# Yum!

# %%
x=int(input())
print(x)
if (x > 0):
    print("Positive")
elif (x < 0):
    print("Negative")
elif (x == 0):
    print("Zero")
# Out:
# 3
# Positive

# %%
hour = 18
password = 'openSesame'
if password=='openSesame':  
    print('User logged on.')
    if hour>17:
        print('Good evening!')
    print('Enter a command:')
# Out:
# User logged on.
# Good evening!
# Enter a command:

# %% [markdown]
# Write a program that reads an integer from input, representing someone's age. If the age is 18 or larger, print out You can vote. If the age is between 0 and 17 inclusive, print out Too young to vote. If the age is less than 0, print out You are a time traveller.

# %%
age = int(input())

if (age >= 18):
    print("You can vote")
elif (age >= 0 and age <= 17):
    print("Too young to vote")
elif (age < 0):
    print("You are a time traveller")
# Out:
# Too young to vote
